# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from scipy import ndimage
import numpy as np
import matplotlib.pyplot as plt
import Image

# %%
image_data = np.array(Image.open("pelicula.JPG"))
image_data.shape
# Out:
# (431, 468, 3)

# %%
im = Image.fromarray(image_data)
figure(figsize=(12,10))
imshow(im)

# %%
r,g,b = image_data.T

# %%
figure(figsize=(20,20))

subplot(131)
imshow(r.T)

subplot(132)
imshow(g.T)

subplot(133)
imshow(b.T)

# %%
r.shape
# Out:
# (468, 431)

# %%
new=r[:,:400].T
figure(figsize=(12,12))
imshow(new)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10d92e998>

# %%
new.shape
# Out:
# (400, 468)

# %%
400*468
# Out:
# 187200

# %%
aux=0
simulated=ones(187200).reshape(400,468)
for i in xrange(400):
    for j in xrange(468):
        if new[i,j]==0:
            simulated[i,j]=new[i,j]
            aux+=1

# %%
aux
# Out:
# 35

# %%
140*100/256
# Out:
# 54

# %%
figure(figsize=(12,12))
imshow(simulated)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10e253758>

# %%
simulated=ones(187200).reshape(400,468)
for i in xrange(400):
    for j in xrange(468):
        if new[i,j]>180:
            simulated[i,j]=new[i,j]
figure(figsize=(12,12))
imshow(simulated)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1102ba5f0>

# %%
simulated=ones(187200).reshape(400,468)
for i in xrange(400):
    for j in xrange(468):
        if new[i,j]>140:
            simulated[i,j]=new[i,j]
figure(figsize=(12,12))
imshow(simulated)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x10cffe950>

# %%
simulated=ones(187200).reshape(400,468)
for i in xrange(400):
    for j in xrange(468):
        if new[i,j]>100:
            simulated[i,j]=new[i,j]
figure(figsize=(12,12))
imshow(simulated)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x1117de7a0>
